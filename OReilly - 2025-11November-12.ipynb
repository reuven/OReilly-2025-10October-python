# %% [markdown]
# # Agenda, week 5
#
# 1. Q&A
# 2. What are modules? What do they give us?
# 3. Different forms of the `import` command
# 4. Developing a simple module
# 5. What happens when we invoke `import`?
# 6. The special `__name__` name in Python
# 7. Python's standard library
# 8. PyPI, `pip`, and `uv`
# 9. AMA -- ask me anything
# 10. What's next?

# %% [markdown]
# # How does `for` give us different values when iterating over different iterables?
#
# We've seen that `for` loops work differently with different types of values:
#
# - With strings, we get each character, one at a time
# - With lists and tuples, we get each element, one at a time
# - With dicts, we get each key, one at a time,
# - With files, we get each line, one at a time
#
# How, without saying much, does the `for` loop work differently?
#
# The answer is in the conversation that it has with the value.
#
# ```python
# for one_item in thing:
#     print(one_item)
# ```
#
# Here, `for` will turn to `thing` and ask: Are you iterable? So long as the value says "yes," the `for` loop believes it. Then, with each iteration, the `for` loop asks `thing` for its next item.
#
# The `for` loop has no idea how many values it'll get, or what they will be. It's all up to the `thing` with which it's speaking. This is very different from many other languages.
#
# Each type of iterable in Python knows what it will give with each iteration when `for` asks for it.
#
# The specification of this conversation is known as a "protocol." THere are lots of protocols in programming. In Python, the "iterator protocol" is one of the most famous and one of the most widely implemented.
#
# If I say, then:
#
# ```python
# for one_line in open('myfile.txt'):     # this for loop is iterating over a file, which gives it one line at a time
#     for one_character in one_line:      # this for loop is iterating over a string (one_line), which gives one character at a time
#         print(one_character)
# ```

# %% [markdown]
# # What are modules?
#
# We've talked several times about the "DRY rule" in programming. That stands for "Don't repeat yourself!"
#
# We've seen several examples of how we can "DRY up" our code:
#
# 1. If the same line repeats (more or less) several times in a row, we can replace it with a loop.
# 2. If the same code repeats (more or less) in several places in our program, we can replace it with a function.
# 3. If the same code repeats (more or less) in several different programs, we can put that code into a *library*.
#
# Libraries are in just about every programming language.
#
# In Python, we call our libraries "modules." A module basically does two things:
#
# 1. Everything I just described about a library, allowing us to package up data and function definitions so that we can use them later on, or share them with colleagues/friends.
# 2. Modules also provide us with "namespaces," a fancy way of saying that we will give last names to our variables. This ensures that if two people are working on different parts of a program, and both use the variable `x`, these variables won't step on each other.
#
# A bit more terminology:
#
# - A module, as we'll see, is implemented in a single file.
# - A "package" is a directory/folder containing one or more modules.

# %% [markdown]
# # Using a module in Python
#
# If I know the name of a module that I want to use, and if it's already installed in my Python system, then I can just use the `import` statement to work with it. "Already installed" is a tricky phrase; for now, we're going to use only things that come with Python, what's known as the "standard library."

# %%
import random     # this is how I use "import" to load the "random" module

# %% [markdown]
# # The syntax of `import`
#
# 1. We use `import` to make use of a module.
# 2. `import` is not a function! So we don't use `()` after it, or around the name of what we want to load.
# 3. The name to the right of `import` is not a string! It's not the name of a file! It's the name of the variable we want to assign the module we have loaded. In this way, it's similar to `def`, which defines functions. Here, we say what module we want to have loaded, and from that name, Python figures out what file to load, and where it is. This means that you *don't* give `import` a string!
# 4. There isn't a standard, easy way to `import` a particular file. Rather, Python has conventions for how module names and filenames are related, and where Python will look for your modules.

# %% [markdown]
# # What can I do with my imported `random` module?
#
# I can ask it to present itself.

# %%
random
# Out:
# <module 'random' from '/Users/reuven/.local/share/uv/python/cpython-3.14.0-macos-aarch64-none/lib/python3.14/random.py'>

# %%
# I can invoke any function that was defined inside of the random module
# In order to do that, I'll use random.NAME, where NAME is something defined

random.randint(0, 100)   # this invokes the "randint" function in the "random" module
# Out:
# 50

# %%
random.randint(0, 100)
# Out:
# 36

# %%
# what names are available in random? We can use the "dir" function to find out

dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
help(random.betavariate)
# Out:
# Help on method betavariate in module random:
#
# betavariate(alpha, beta) method of random.Random instance
#     Beta distribution.
#
#     Conditions on the parameters are alpha > 0 and beta > 0.
#     Returned values range between 0 and 1.
#
#     The mean (expected value) and variance of the random variable are:
#
#         E[X] = alpha / (alpha + beta)
#         Var[X] = alpha * beta / ((alpha + beta)**2 * (alpha + beta + 1))

# %% [markdown]
# # Exercise: Guessing game
#
# 1. `import random`
# 2. Use `random.randint`, which takes two integer arguments (the highest and lowest possible values), and use it to generate a random number.
# 3. Allow the user to guess the number repeatedly:
#     - If the user enters a non-number, scold them
#     - If the user enters a number, and it's too low, tell them
#     - If the user enters a number, and it's too high, tell them
#     - If the user enters a number, and they guess right, tell them and exit
#
# Example:
#
#     Guess: 50
#     Too low; try again
#     Guess: 75
#     Too high; try again
#     Guess: Stop!
#     Stop! is not numeric. Try again
#     Guess: 62
#     You got it!

# %%
import random

number = random.randint(0, 100)   # generate a number, and assign to the "number" variable

while True:    # we don't know how many times the user will guess!
    s = input('Guess: ').strip()    # here, we get a string from the user

    if not s.isdigit():   # if this isn't a numeric string...
        print(f'{s} is not numeric. Try again!')
        continue

    guess = int(s)  # if s contains only digits, we'll turn it into an integer, and assign to guess

    if guess == number:
        print('You got it!')
        break   # exit from the while loop

    elif guess < number:
        print('Too low!')

    else:
        print('Too high!')
# Out:
# Guess:  50
# Too low!
# Guess:  75
# Too low!
# Guess:  90
# Too low!
# Guess:  95
# Too high!
# Guess:  93
# Too high!
# Guess:  92
# You got it!

# %% [markdown]
# # Where is `random`? How did Python know where to load it from?
#
# When we say `import random`, Python looks for a file called `random.py`. Where? In every directory mentioned in the variable `sys.path`.  That value is a list of strings, describing the directories in which Python should look. Python runs a `for` loop on that list, looking for `random.py` in each directory, one at a time. The first match wins, and is loaded.
#
# I'll add that before looking in `sys.path`, Python looks in the current directory. If you're using Jupyter, then "the current directory" is wherever you're running Jupyter from. If you're using Jupyter Lite, then it'll look in the main directory on the left of y our screen.

# %%
sys.path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sys.path
#
# NameError: name 'sys' is not defined

# %%
# we first have to import sys -- not to get its functionality, but to have the name available for us to use
import sys

sys.path
# Out:
# ['/Users/reuven/.local/share/uv/python/cpython-3.14.0-macos-aarch64-none/lib/python314.zip',
#  '/Users/reuven/.local/share/uv/python/cpython-3.14.0-macos-aarch64-none/lib/python3.14',
#  '/Users/reuven/.local/share/uv/python/cpython-3.14.0-macos-aarch64-none/lib/python3.14/lib-dynload',
#  '',
#  '/Users/reuven/Courses/Current/OReilly-2025-10October-python/.venv/lib/python3.14/site-packages']

# %%
random
# Out:
# <module 'random' from '/Users/reuven/.local/share/uv/python/cpython-3.14.0-macos-aarch64-none/lib/python3.14/random.py'>

# %%
# KD

import random

def guessing_game():
    answer = random.randint(0,100)
    while True:
        useranswer = int(input('guess the number between 1 and 100:'))
        if useranswer > answer:
            print(f'too high, guess again')
        elif useranswer < answer:
            print(f'too low, guess again')
        elif useranswer == answer:
            print(f'you got it!')
            break
        else:
            print(f'you need to pick a number between 1 and 100')

# %%
# I want to use randint a lot. Do I really need to say random.randint each time?

random.randint(0, 50)
# Out:
# 5

# %%
random.randint(2, 10)
# Out:
# 4

# %%
random.randint(3, 30)
# Out:
# 10

# %%
# this is a pain! It's annoying to write "random." before each instance of randint

randint(10, 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # this is a pain! It's annoying to write "random." before each instance of randint
# ----> 3 randint(10, 100)
#
# NameError: name 'randint' is not defined

# %% [markdown]
# # `randint` is an *attribute*
#
# Attributes in Python must come after a `.`, indicating to whom the attribute belongs.
#
# Just as there isn't a `split` method, but it's really `str.split` (a string method), there's also no `randint` method, but rather `random.randint`.
#
# Except... so many people want to shorten their code, and are tired of writing everything out in long form, that actually there is a way around this.

# %%
# from .. import syntax

from random import randint

# %% [markdown]
# # What does `from .. import` do?
#
# 1. When you use `from .. import`, the *entire* module is loaded into memory. This is not a way to save memory if you only want part of a module in your program.
# 2. The module's name will *not* be defined as as variable. In this case, `random` won't be defined.
# 3. But the thing you name *will* be defined. So in this case, `randint` will be defined as a function which you can invoke without `random.` before its name.
# 4. If you want, you can say both `import random` and `from random import randint`. Doing that lets you use the entire `random` module, but also lets you use `randint` without writing the module name first.

# %% [markdown]
# # Aliases
#
# Sometimes, you want to import a module, but you want to give it a different name. In some cases, this is because the name will clash with something else. In other cases, it's because the name is hard to remember, or too long. And in other cases, it's because the entire community has agreed on a set of conventions for what to call something.
#
# For that, you can use `import MOD as ALIAS`. In that case, the module is loaded, but you don't access it via the normal name. Only the alias is defined.

# %%
import random as r    # this imports random. but defines "r" to be the variable in which the module is located

# %%
r.randint(0, 100)
# Out:
# 68

# %%
from random import randint as ri   # here, I define "ri" which refers to random.randint

# %% [markdown]
# # Conflicts
#
# One of the reasons we use modules is for their *namespaces*, that by importing a module, all of the names defined in that module are only available via the module name and `.`. This means we cannot have conflicts.
#
# The moment you start to use `from .. import` or `import .. as`, you open the door to such conflicts. They'll only happen among names that you explicitly import. If you stick with just plain ol' `import`, there are no such problems.

# %%
# don't say

# from a import x
# from b import x

import a   # I can use a.x
import b   # I can use b.x
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 6
#       1 # don't say
#       2
#       3 # from a import x
#       4 # from b import x
# ----> 6 import a   # I can use a.x
#       7 import b   # I can use b.x
#
# ModuleNotFoundError: No module named 'a'

# %% [markdown]
# # Four ways to use `import`
#
# - `import MODNAME`, looks for `MODNAME.py` in `sys.path`
# - `import MODNAME as ALIAS`, looks for `MODNAME.py` in `sys.path`, but defines `ALIAS` as the variable referring to the module
# - `from MODNAME import NAME`, loads `MODNAME`, but only defines `NAME` as a global variable. `MODNAME` is not available.
# - `from MODNAME import NAME as ALIAS`, load `MODNAME`, only defines `ALIAS` as as global variable, referring to `NAME`.
# - **BONUS**: `from MODNAME import *` -- this means all of the names in `MODNAME` should be defined as global variables outside of the module This is an absolutely **TERRIBLE** idea most of the time! It removes all of the goodness of namespaces and keeping things separate.

# %% [markdown]
# # Next up
#
# - Write a simple module
# - `import it`
# - Explore how these mechanisms work

# %% [markdown]
# # Writing a module
#
# Writing a module in Python is very easy and straightforward.
#
# - We create a file
# - The filename ends in `.py`
# - The file is in the same directory as the program we'll be importing it into
# - The file contains definitions for variables and functions.

# %%
# I'm now going to load up mymod with "import"
# by saying "import mymod", Python looks in the current directory for mymod.py. It finds it, and loads
#   the contents of the file into a module object, and then assigns that to mymod


import mymod

# %%
type(mymod)
# Out:
# module

# %%
dir(mymod)   # what names are defined here?
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %% [markdown]
# # Even empty modules have attributes!
#
# Python defined a number of "dunder" (double underscore, before and after the name) names in every module, even those that are empty. Some of these are interesting to us right now:
#
# - `__file__` is the name of the file that we loaded
# - `__name__` is the name of the module itself

# %%
mymod.__file__
# Out:
# '/Users/reuven/Courses/Current/OReilly-2025-10October-python/mymod.py'

# %%
mymod.__name__
# Out:
# 'mymod'

# %%
# let's import mymod again!

import mymod

# %%
dir(mymod)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %% [markdown]
# When you `import` a module, that's the first and *only* time in a Python program that it will be imported. After that, every `import` just refers back to the already imported version.
#
# This is normally fine. In Jupyter, though, we have a long-running Python process. This can cause problems when developing. Luckily, Python comes with an `importlib` module which is for developers working on modules. I can say

# %%
from importlib import reload

# %%
# the reload function takes a module as an argument, and reloads it

reload(mymod)
# Out:
# <module 'mymod' from '/Users/reuven/Courses/Current/OReilly-2025-10October-python/mymod.py'>

# %%
dir(mymod)  # now that we have reloaded it, we will get any updates in the module
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'hello',
#  'x',
#  'y']

# %%
mymod.x
# Out:
# 100

# %%
mymod.y
# Out:
# [10, 20, 30]

# %%
mymod.hello('world')
# Out:
# 'Hello, world, from mymod!'

# %% [markdown]
# # Exercise: `menu` module
#
# 1. Create a new file in the same directory as Jupyter, called `menu.py`. This module (the theory goes) will be used by all of the programs in our department to display a variety of options, and let the user choose from among them.
# 2. In the module, define a function, `textlen`, that takes a string and returns the length of that string.
# 3. Then, outside of the module, you should `import menu` and then invoke `menu.textlen` on a string to get its length. Does it work?

# %%
import menu              # load menu.py, the module, into memory
menu.textlen('hello')    # invoke the textlen function from the menu module
# Out:
# 5

# %% [markdown]
# # Exercise: Menus
#
# 1. In the `menu.py` module, now define a function called `menu`. (Yes, it's totally normal to define a function in a module, where both the function and module have the same name.) This function should take a list of strings, the options from which the user should choose. The user is then asked to choose one of them. If/when the user does, the choice is returned to the function's caller. If the user chooses an illegal value, then they are scolded and asked to try again.
# 2. Use `reload` to reload the module. (Another option is to restart the kernel in Jupyter with the "kernel -> restart" menu command at the top of the screen. Invoke `menu.menu(['a', 'b', 'c'])`. Capture the user's response and print it.
#
# ```python
# import menu
# user_choice = menu.menu(['a', 'b', 'c'])
# print(f'User chose {user_choice}')
# ```

# %%
reload(menu)
# Out:
# <module 'menu' from '/Users/reuven/Courses/Current/OReilly-2025-10October-python/menu.py'>

# %%
my_choice = menu.menu(['a', 'b', 'c'])
# Out:
# Choose from ['a', 'b', 'c']:  q
# q is not valid; try again
# Choose from ['a', 'b', 'c']:  abc
# abc is not valid; try again
# Choose from ['a', 'b', 'c']:  A
# A is not valid; try again
# Choose from ['a', 'b', 'c']:  b

# %%
my_choice
# Out:
# 'b'

# %%
# contents of menu.py

def textlen(text):
    return len(text)

def menu(choices):
    while True:
    
        user_choice = input(f'Choose from {choices}: ').strip()
    
        if user_choice in choices:
            return user_choice

        print(f'{user_choice} is not valid; try again')

# %% [markdown]
# # How does `import` work?
#
# At a simple level:
#
# - I say `import`
# - The file is found
# - The file is loaded
# - I now have access to all of the file's definitions under the module's namespace as attributes
#
# If I `import a`, I then have `a.b`, `a.c`, and `a.d`.
#
# But wait... How can it be that just before `import mymod`, neither the variable `mymod` nor any of the attributes on it are defined. But immediately have the `import`, they are?
#
# The only way that this can work is if a module's code is executed when we `import` the module. Meaning: If I say `import mymod`, then the entire file, from start to finish, is executed. Thanks to the fact that I only assign to variables and define functions, it doesn't seem weird.

# %%
reload(mymod) # same as import, but after the module has been loaded once
# Out:
# Now entering mymod!
# Now leaving mymod!
# <module 'mymod' from '/Users/reuven/Courses/Current/OReilly-2025-10October-python/mymod.py'>

# %% [markdown]
# When you `import` a module, its code is executed from the start to the end.
#
# If you are weird/foolish/daring enough to do so, you can have non-definition code in there, as well, such as `print`.
#
# Inside of our module, we have defined global (i.e., out of function) variables. But outside of our module, when we `import` it, we don't see variables; we see attributes.
#
# That is:
#
# - The global variable `x` defined in `mymod.py` is available to us as `mymod.x`, an attribute on the `mymod` module.
# - The global variable `y` defined in `mymod.py` is available to us as `mymod.y`, an attribute on the `mymod` module.
# - The function `hello` defined in `mymod.py` is available to us as `mymod.hello`, an attribute on the `mymod` module.
#
# What other attributes are on our module object? We have, for example, `__name__`. This contains the module's name, as a string.
#
# If it's an attribute on the module object, then maybe `__name__` is a global variable inside of the module itself?

# %%
reload(mymod)
# Out:
# Now entering mymod!
# Now leaving mymod!
# <module 'mymod' from '/Users/reuven/Courses/Current/OReilly-2025-10October-python/mymod.py'>

# %% [markdown]
# From this, we see that `__name__` isn't just an attribute on a module object. It's also a global variable, one that tells us the current namespace in which Python is functioning for that file.
#
# In other words, it tells us the "surname" we should associate with variables in that file.

# %% [markdown]
# In my terminal, I ran:
#
# ```
# ❯ python mymod.py
# ```
#
# And I got:
#
# ```
# Now entering __main__!
# Now leaving __main__!
# ```
#
# `__name__` is a variable that tells you the namespace in which the current file is located. There are two possible values for `__name__`:
#
# 1. If the file was imported, then `__name__` is a string, the name of the file. So when we say `import mymod`, then inside of `mymod`, `__name__` is the string `mymod`.
# 2. If the file was *not* imported, meaning that it was run as a standalone program, then its value of `__name__` is special, the string `'__main__'`, indicating that this is the first file to be run in the Python process.
#
# This lets us distinguish between when a file is run as a program and when it is imported as a module. That allows us to do interactive things when it's run interactively, but not when it's imported.
#
# How can I make this distinction? The module is executed, line by line, when we `import` it. So we can use `if` to check the value of `__name__`.
#
# This leads to one of the most common, most famous, and most misunderstood lines in all of Python:
#
# ```
# if __name__ == '__main__':
# ```
#
# This line is very common in Python modules. It means:
#
# - Only do the things below this line if the current file was run directly by the user.
# - Ignore the things below this line if the current file was imported.

# %%
reload(mymod)
# Out:
# <module 'mymod' from '/Users/reuven/Courses/Current/OReilly-2025-10October-python/mymod.py'>

# %% [markdown]
# I've created a module that knows how to provide functionality as a library, but also knows how to behave as a standalone program!

# %% [markdown]
# # Next up
#
# - Review the whole `__name__` and `'__main__'` thing
# - A little more on writing modules
# - Python standard library
# - PyPI, pip, uv, and the rest

# %% [markdown]
# # Things to remember
#
# 1. When we `import MOD`, the file `MOD.py` executes from start to finish. In theory, we could put any code in there that we want, and it'll run when we `import` the module. In reality, we normally just put in function and variable definitions.
# 2. The `__name__` attribute on the module is available inside of the module's code as a global variable, `__name__`. It can have one of two values:
#     - A string, the same as the module filename, if it was imported.
#     - A string, `'__main__'`, indicating that this module was the first program run in the current Python process.
# 3. By having a line, `if __name__ == '__main__'`, our program can have special functionality that only runs when it is executed as a program, rather than when it is imported as a library.

# %% [markdown]
# # So what?
#
# Why would I care? Why would I want to have special functionality that runs only when the module is executed as a standalone program?
#
# There are many different things that module authors want to have happen when their modules are executed:
#
# 1. Run automated tests.
# 2. Use the functionality in the module in an interactive way, asking the user to enter some basic values and then "showing off" what the module can do with those inputs
# 3. Run some demos with the module's functionality.
#
# Just about every module in the Python world have these `if __name__` lines.
